# %% [markdown]
# <a href="https://colab.research.google.com/github/Ridho2905/KKA-X-Semester-1/blob/main/1_Fungsi_print_Muhammad_Ridho_X_11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama:muhammad ridho
#
# Kelas:x-11
#
# Absen:22

# %% [markdown]
# #MENAMPILKAN TEKS BEBAS

# %%
print("muhammad ridho")
# Out:
# muhammad ridho

# %% [markdown]
# #MENAMPILKAN NILAI VARIABEL

# %%
Nama_saudara = "iqbal"
print(Nama_saudara)
# Out:
# iqbal

# %%
Jumlah_saudara = "1"
print(Jumlah_saudara)
# Out:
# 1

# %% [markdown]
# #Menampilkan teks bebas

# %% [markdown]
# ##MENAMPILKAN TEKS BEBAS DAN NILAI VARIABEL MENGGUNAKAN TANDA KOMA

# %%
print("Saya memiliki saudara sebanyak", Jumlah_saudara, "nama saudara saya", Nama_saudara)
# Out:
# Saya memiliki saudara sebanyak 1 nama saudara saya iqbal

# %% [markdown]
# ##MENAMPILKAN TEKS BEBAS DAN NILAI VARIABEL MENGGUNAKAN PLUS

# %%
print("saya memiliki saudara sebanyak"+str(Jumlah_saudara) +"."+ "nama saudara saya adalah"+ Nama_saudara + ".")
# Out:
# saya memiliki saudara sebanyak1.nama saudara saya adalahiqbal.

# %% [markdown]
# ##menampilkan Teks bebas dan nilai variabel menggunakan f string

# %%
print(f"saya memiliki saudara {Jumlah_saudara}. Nama saudara saya adalah {Nama_saudara}. ")
# Out:
# saya memiliki saudara 1. Nama saudara saya adalah iqbal.

# %% [markdown]
# ##ESCAPE CHARACTER

# %%
print("Nama: Muhammad ridho")
print("Kelas: X-11")
print("No absen: 22")
# Out:
# Nama: Muhammad ridho
# Kelas: X-11
# No absen: 22

# %%
print("Nama: Muhammad ridho\nKelas: X-11\nNo absen: 22")
# Out:
# Nama: Muhammad ridho
# Kelas: X-11
# No absen: 22

# %%
print("""Nama\t\t: Muhammad ridho
Kelas\t\t: X-11
No. Absen\t: 22""")
# Out:
# Nama		: Muhammad ridho
# Kelas		: X-11
# No. Absen	: 22

# %%
print("Muhammad Ridho")
# Out:
# Muhammad Ridho

# %%
print('Muhammad Ridho')
# Out:
# Muhammad Ridho

# %%
print('Habib Ja\'far')
# Out:
# Habib Ja'far

# %%
print("Habib Ja'far")
# Out:
# Habib Ja'far

# %%
print("Bu Shinta berkata, \"Harap fokus menyimak!\".")
# Out:
# Bu Shinta berkata, "Harap fokus menyimak!".

# %%
print('Bu Shinta berkata,"Harap fokus menyimak!".')
# Out:
# Bu Shinta berkata,"Harap fokus menyimak!".

# %%
print("Lokasi penyimpanan tugas KKA di D:\\MAN Demak\\KKA\\Tugas")
# Out:
# Lokasi penyimpanan tugas KKA di D:\MAN Demak\KKA\Tugas

# %% [markdown]
# ##FUNGSI PARAMETER

# %%
nama_siswa_1="Dafanes"
nama_siswa_2="Adzka"
nama_siswa_3="Haydar"
print(nama_siswa_1, nama_siswa_2, nama_siswa_3, sep="-")
# Out:
# Dafanes-Adzka-Haydar

# %%
print("nama_siswa_1")
# Out:
# nama_siswa_1

# %%
print(nama_siswa_3, end="#")
print(nama_siswa_2, end="#")
print(nama_siswa_1, end="#")
print(nama_siswa_2)
# Out:
# Haydar#Adzka#Dafanes#Adzka
