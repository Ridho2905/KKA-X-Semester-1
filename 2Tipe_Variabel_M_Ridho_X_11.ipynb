# %% [markdown]
# <a href="https://colab.research.google.com/github/Ridho2905/KKA-X-Semester-1/blob/main/2Tipe_Variabel_M_Ridho_X_11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama:Muhammad Ridho
#
# Kelas:X.11
#
# No.absen:29

# %% [markdown]
# #Konsep Dasar Variabel

# %%
print("muhamadridho174@gmail.com")
print("muhamadridho174@gmail.com")
print("muhamadridho174@gmail.com")
# Out:
# muhamadridho174@gmail.com
# muhamadridho174@gmail.com
# muhamadridho174@gmail.com

# %%
email_user_1 ="muhamadridho174@gmail.com"

print(email_user_1)
print(email_user_1)
print(email_user_1)
# Out:
# muhamadridho174@gmail.com
# muhamadridho174@gmail.com
# muhamadridho174@gmail.com

# %% [markdown]
# #Peraturan Penamaan Variabel

# %%
#Hanya diperbolehkan menggunakan huruf,angka,dan underscore
email user 2 ="iqbalgozali838@gmail.com"

print(email user 2)
# Out:
#   File "/tmp/ipython-input-4098195189.py", line 2
#     email user 2 ="iqbalgozali838@gmail.com"
#           ^
# SyntaxError: invalid syntax

# %%
emailuser2 ="iqbalgozali838@gmail.com"

print(emailuser2)
# Out:
# iqbalgozali838@gmail.com

# %%
#Tidak boleh didahului oleh angka
3_email_user ="iqbalgozali838@gmail.com"

print(3_email_user)
# Out:
#   File "/tmp/ipython-input-1366228631.py", line 2
#     3_email_user ="iqbalgozali838@gmail.com"
#      ^
# SyntaxError: invalid decimal literal

# %%
email_user_3 ="iqbalgozali838@gmail.com"

print(email_user_3)
# Out:
# iqbalgozali838@gmail.com

# %%
For ="muhamadridho174@gmail.com"

print(For)

# %%
print ="iqbalgozali838@gmail.com"

print(print)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1059188716.py in <cell line: 0>()
#       1 print ="iqbalgozali838@gmail.com"
#       2
# ----> 3 print(print)
#
# TypeError: 'str' object is not callable

# %%
Print = "iqbalgozali838@gmail.com"

print(Print)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-642532476.py in <cell line: 0>()
#       1 Print = "iqbalgozali838@gmail.com"
#       2
# ----> 3 print(Print)
#
# TypeError: 'str' object is not callable

# %% [markdown]
# #Penggunaan Operator di Python

# %%
#Tanpa Variabel
print (20 + 3)
# Out:
# 23

# %%
#Operator disimpan ke dalam Variabel

roti_swiss_alex = 20
roti_swiss_nazril = 3

print(roti_swiss_alex + roti_swiss_nazril)
# Out:
# 23

# %%
#Hasil operasi di simpan ke dalam Variabel
jumlah_roti_swiss = 20+3

print(jumlah_roti_swiss)
# Out:
# 23

# %%
#Operand dan hasil operasi di simpan ke Variabel
roti_swiss_alex = 20
roti_swiss_nazril =3

jumlah_roti_swiss = roti_swiss_alex + roti_swiss_nazril

print(jumlah_roti_swiss)
# Out:
# 23

# %% [markdown]
# #Tugas

# %%
print(24 * 3)
# Out:
# 72

# %%
total_jumlah_botol =24*3

print(total_jumlah_botol)
# Out:
# 72

# %%
banyak_botol_per_kardus = 24
jumlah_kardus = 3

print(banyak_botol_per_kardus * jumlah_kardus)
# Out:
# 72

# %%
banyak_botol_per_kardus = 24
jumlah_kardus = 3

total_jumlah_botol = banyak_botol_per_kardus * jumlah_kardus

print(total_jumlah_botol)
# Out:
# 72

# %% [markdown]
# #Operator aritmatika

# %%
buku_tulis_himam = 55
buku_tulis_fico = 15

# %%
#pertambahan
print(buku_tulis_himam + buku_tulis_fico)
# Out:
# 70

# %%
#pengurangan

selisih_buku_tulis = buku_tulis_himam - buku_tulis_fico
print(selisih_buku_tulis)
# Out:
# 40
